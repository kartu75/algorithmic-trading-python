# %%
import pandas as pd
import yfinance as yf
import numpy as np
# !pip install xlsxwriter
import xlsxwriter
from scipy import stats
import math
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 175.3/175.3 kB 2.5 MB/s eta 0:00:00 0:00:01
# ...

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
stocks=pd.read_csv('/content/drive/MyDrive/sp_500_stocks.csv')
stocks.head()
# Out:
#   Ticker
# 0      A
# 1    AAL
# 2    AAP
# 3   AAPL
# 4   ABBV

# %%
ticker=yf.Ticker('AAPL')
price_to_earnings_ratio=ticker.info.get('trailingPE','N/A')
print(price_to_earnings_ratio)
# Out:
# 37.328083

# %%
my_coloumns=['Ticker','Price','Trailing-Price-Earnings-Ratio','Number of Shares to Buy']
final_dataframe=pd.DataFrame(columns=my_coloumns)
for symbol in stocks['Ticker']:
  newrow={
    'Ticker':symbol,
    'Price' :ticker.info.get('currentPrice') or ticker.info.get('regularMarketPrice', 'N/A'),
    'Trailing-Price-Earnings-Ratio':symbol.info.get('trailingPE','N/A'),
    'Number of Shares to Buy':'N/A'
    
        }
  final_dataframe=pd.concat(final_dataframe,pd.DataFrame([newrow]),ignore_index=True)
final_dataframe
